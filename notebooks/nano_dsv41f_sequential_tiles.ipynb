# %% [markdown]
# # Archived experiment
#
# The isolated 128/256/512 sequential-tile study has been superseded by the final-attention search and full-model validation.
#
# Archived copy: `notebooks/archive/nano_dsv41f_sequential_tiles.ipynb`.
# Current entry point: `notebooks/nano_dsv41f_final_attention_tuning.ipynb`.
