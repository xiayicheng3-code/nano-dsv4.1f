# %% [markdown]
# # Archived experiment
#
# The 4/8/24-row profiling notebook is a historical systems experiment and is no longer an active entry point.
#
# Archived copy: `notebooks/archive/nano_dsv41f_pretrain_profile.ipynb`.
# Measured provenance remains under `docs/experiments/`.
