# %% [markdown]
# # Archived experiment
#
# This broad pretraining stress notebook is retained for historical reproducibility, not as a current training entry point.
#
# Archived copy: `notebooks/archive/nano_dsv41f_pretrain_stress.ipynb`.
# Current training-stage policy: `docs/training_stages.md`.
# Current TPU follow-ups: `notebooks/nano_dsv41f_final_attention_tuning.ipynb` and `notebooks/nano_dsv41f_moe_buffers.ipynb`.
